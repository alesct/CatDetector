# %%
import joblib

model = joblib.load('cat_detector_model.pkl')

joblib.dump(model, 'model_compressed.pkl.gz', compress=('gzip', 3))

print("Compression complete. Your original file was not altered.")
# Out:
# Compression complete. Your original file was not altered.
